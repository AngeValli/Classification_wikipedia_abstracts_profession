# %% [markdown]
# <a href="https://www.kaggle.com/code/angevalli/classify-people-by-profession-from-wikipedia?scriptVersionId=133902187" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# The goal of this lab is to classify Wikipedia abstracts about people by their professions. For example, the professions of Elvis Presley are "singer" and "actor".
#
# === Input ===
#
# The input for training is a file wiki-train.json, which contains Wikipedia abstracts in the following form:
#    {"title": "George_Washington",
#     "summary": "George Washington was one of the ..."
#     "occupations": ["yago:politician"]}
#
# The input for testing is a file wiki-test.json, which contains Wikipedia abstracts of the same shape without the occupations:
#
#    {"title": "Douglas_Adams",
#     "summary": "Douglas Noel Adams was ..."}
#
# === Output ===
#
# The output shall be a JSON file that assigns each Wikipedia abstract to a set of occupations:
#    {"title": "Douglas_Adams",
#     "occupations": ["Q36180", "Q28389"]}
#
# === Datasets ===
#
# We provide 3 datasets:
# 1) a training dataset, which has the labels
# 2) a development dataset, which has the labels
# 3) a testing dataset, which does not have the labels
#
# === Suggestions for improving the model ===
#
# 1) Select a suitable theta value
# Reference: held-out set, cross validation, grid search...
#
# 2) Use pre-trained embeddings
# reference: word2vector, GloVe, FastText...
#
# 3) Add extra features
# reference: stop words, part-of-speech...
#
# 4) Try other neural networks
# reference: CNN, RNN, Attention, Transformer
#
# 5) Avoid overfitting
# reference: regularization, dropout...
#
# 6) Adjust other parameters
# reference: learning rate, batch_size, epoch, layer's dimension

# %%
import os
for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/wikipedia-abstracts/wiki-dev.json.gzde
# /kaggle/input/wikipedia-abstracts/wiki-dev.json
# /kaggle/input/wikipedia-abstracts/wiki-train.json.gzde
# /kaggle/input/wikipedia-abstracts/wiki-test.json.gzde
# /kaggle/input/wikipedia-abstracts/wiki-test.json/new_wiki-test.json
# /kaggle/input/wikipedia-abstracts/wiki-train.json/new_wiki-train.json
# /kaggle/input/glove6b200d/glove.6B.200d.txt

# %% [markdown]
# ### Preprocessing

# %%
# !cp /kaggle/input/wikipedia-abstracts/wiki-test.json.gzde /kaggle/working/wiki-test.json.gz
# !cp /kaggle/input/wikipedia-abstracts/wiki-train.json.gzde /kaggle/working/wiki-train.json.gz
# !cp /kaggle/input/wikipedia-abstracts/wiki-dev.json.gzde /kaggle/working/wiki-dev.json.gz

# %%
# Import the necessary modules and methods
import nltk
import numpy as np
from tqdm import tqdm

# Import functions from keras
from keras.layers import Embedding, Dense, Dropout, Flatten
from keras.models import Model, load_model
import keras.backend as K
from keras import Sequential

# Import some basic packages
import os
import sys
import json

# Download punkt  in case of error in last cell
nltk.download("punkt")
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sys.path.insert(0,"/kaggle/working/")

# Import custom functions
from utility_script_people_classification import load_vocabulary, read_dataset, get_label, f1_score, load_data, gen_vocabulary

# %%
# input files
# [ train_file ] is a training dataset that contains 266K samples.
# [ test_file ] is a testing dataset that contains 200K samples. You can test your model based on this file.
# [ predict_file ] is a predicting dataset that contains 201K samples. Each sample in this file does not have occupation labels.

train_file = "/kaggle/working/wiki-train.json.gz"
test_file = "/kaggle/working/wiki-dev.json.gz"
predict_file = "/kaggle/working/wiki-test.json.gz"

# output files
# [ vocab_file ] has a word vocabulary that defines which words participate in this task.
# The default vocabulary is generated by our methods from training dataset,
# but you can create it in a way you like.
# [ model_file ] is used for store your trained model
# [ result_file ] is file that stores your predicted occupations.

vocab_file = "/kaggle/working/vocab.txt"
model_file = "/kaggle/working/my_model.h5"
result_file = "/kaggle/working/result.json"

# %% [markdown]
# We implement GloVe embedding

# %%
# Hyper-parameters: You don't have to change these, but you can.
# [ embedding_dimension ] the dimensions of word embeddings
# [ maximal_sentence_length ] the maximum length of each sentence
# [ number_of_labels ] the number of occupations
# [ epochs ] training epochs. Adjust this parameters to avoid overfitting and underfitting.
# [ batch_size ] the number of samples. It determines how many samples would be fed into your model.
# This size of this parameter also depends on how good your hardware is.
# [ theta ] A threshold to determine whether to assign a specific occupation label given a input sample.
# A suitable theta value will help your model

embedding_dimension = 200
maximal_sentence_length = 100
number_of_labels = 20
epochs = 20
batch_size = 32
theta = 0.45 # Change theta value
validation_split = 0.1

# %%
# Create an embedding vector linked to only the data we have with glove
# As default embedding dimension is 200, we consider here the 200 Dimensions file of GloVe Dataset
embeddings_dictionary = dict()
glove_file = open("/kaggle/input/glove6b200d/glove.6B.200d.txt", encoding="utf8")
for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = np.asarray(records[1:], dtype="float32")
    embeddings_dictionary[word] = vector_dimensions
glove_file.close()

# %%
def create_model(embedding_matrix): #embedding_matrix as parameter instead of vocab
    '''
    :param vocab: a vocabulary dictionary which looks like {'python':0, 'java':1 ......}
    :return:
    '''
    model = Sequential()
    model.add(Embedding(input_dim=len(embedding_matrix), 
                        output_dim=embedding_dimension, 
                        weights=[embedding_matrix],
                        input_length=maximal_sentence_length,
                        trainable=False))
    model.add(Flatten())
    model.add(Dense(32, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(number_of_labels, activation="sigmoid"))
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["binary_accuracy"])
    return model

# %%
def train(debug):
    '''
    train your model.
    :param debug:whether to use a small fraction of samples
    :return:
    '''

    # prepare data
    vocab_to_id = load_vocabulary(vocab_file)
    data_x, data_y, embedding_matrix = read_dataset(train_file, vocab_to_id, maximal_sentence_length, train=True, embeddings_dictionary=embeddings_dictionary, embedding_dimension=embedding_dimension, debug=debug) # Adding embedding_matrix
    data_x_test, data_y_test, _ = read_dataset(test_file, vocab_to_id, maximal_sentence_length, train=False, debug=debug)

    # create a model
    model = create_model(embedding_matrix)
    model.summary()  

    # train
    print("start to train, data size = {a}".format(a=len(data_x)))
    model.fit(data_x, data_y, validation_split=validation_split, epochs=epochs, batch_size=batch_size, validation_data=(data_x_test, data_y_test)) # Adding validation data

    # save model
    model.save(model_file)

def evaluate_on_dev(debug):
    '''
    evaluate your model on the development dataset.

    :param debug:whether to use a small fraction of samples
    :return:
    '''

    # prepare data
    vocab_to_id = load_vocabulary(vocab_file)
    data_x, data_y, _ = read_dataset(test_file, vocab_to_id, maximal_sentence_length, train=False, debug=debug)
    raw_samples = list(load_data(test_file))
    print("start to do validation, data size = {a}".format(a=len(data_x)))
    _, id_to_labels = get_label()
    pred_labels, true_labels = list(), list()

    # load model
    model = load_model(model_file)

    # predict each sample
    for summary, label, raw in zip(data_x, data_y, raw_samples):
        result = model.predict(np.array([summary]))[0]
        pred = set([id_to_labels[i] for i, prob in enumerate(result) if prob > theta])
        true = set([id_to_labels[index] for index, e in enumerate(label) if e == 1])
        pred_labels.append(pred)
        true_labels.append(true)

        # print wrong prediction
        print("Title:" + raw.title)
        wrong_occupations = pred - true
        if len(wrong_occupations) > 0:
            print("[ wrong prediction ] this person does not have the occupations:{a}".format(a=wrong_occupations))
        missing_occupations = true - pred
        if len(missing_occupations) > 0:
            print("[ missing prediction ] your prediction miss the occupations:{b}".format(b=missing_occupations))
        print("---------------------------")

    # calculate metrics
    true_labels
    f1, precision, recall = f1_score(true_labels, pred_labels)
    print("result on validation set, f1 : {a}, precision : {b}, recall : {c}.".
          format(a=f1, b=precision, c=recall))


def predict_on_test(debug):
    '''
    :param debug: whether to use a small fraction of samples
    :return:
    '''

    # prepare data
    _, id_to_labels = get_label()
    vocab_to_id = load_vocabulary(vocab_file)
    model = load_model(model_file)
    datax, _, _= read_dataset(predict_file, vocab_to_id, maximal_sentence_length, train=False, debug=debug)
    raw_samples = list(load_data(predict_file))

    # predict
    r_f = open(result_file, "w", encoding="utf8")
    for data, raw_sample in tqdm(zip(datax, raw_samples)):
        result = model.predict(np.array([data]))[0]
        pred = [id_to_labels[i] for i, prob in enumerate(result) if prob > theta]
        r_f.write(json.dumps({
                            "title": raw_sample.title,
                            "occupations": pred
                        }) + "\n")

# %%
# create a vocabulary file if does not exist
if not os.path.exists(vocab_file):
    gen_vocabulary(train_file, vocab_file)

# train & evaluate & predict
# note: the switch 'debug' is True means only using a small fraction of samples, which can save time to debug your code.
# Change 'debug' to False when your want to train and test on all samples.
debug = True
train(debug=debug)
# Out:
# 266938it [02:18, 1931.88it/s]
# done! The size of vocabulary is 344677.
# 100it [00:00, 975.91it/s]
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e0cd0>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a90>
# 100it [00:00, 1246.70it/s]
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3a00>
# <utility_script_people_classification.InputSample object at 0x7d45dc9e3970>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 200)          80000000
#
#  flatten (Flatten)           (None, 20000)             0
#
#  dense (Dense)               (None, 32)                640032
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 20)                660
#
# =================================================================
# Total params: 80,640,692
# Trainable params: 640,692
# Non-trainable params: 80,000,000
# _________________________________________________________________
# start to train, data size = 100
# Epoch 1/20
# 4/4 [==============================] - 4s 77ms/step - loss: 0.6735 - binary_accuracy: 0.5990 - val_loss: 0.5594 - val_binary_accuracy: 0.7070
# Epoch 2/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6090 - binary_accuracy: 0.7155 - val_loss: 0.5631 - val_binary_accuracy: 0.7395
# Epoch 3/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6002 - binary_accuracy: 0.7135 - val_loss: 0.5567 - val_binary_accuracy: 0.7525
# Epoch 4/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5716 - binary_accuracy: 0.7235 - val_loss: 0.5351 - val_binary_accuracy: 0.7680
# Epoch 5/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5621 - binary_accuracy: 0.7345 - val_loss: 0.5133 - val_binary_accuracy: 0.7715
# Epoch 6/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5486 - binary_accuracy: 0.7460 - val_loss: 0.5019 - val_binary_accuracy: 0.7815
# Epoch 7/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5190 - binary_accuracy: 0.7485 - val_loss: 0.4969 - val_binary_accuracy: 0.8015
# Epoch 8/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5281 - binary_accuracy: 0.7595 - val_loss: 0.4994 - val_binary_accuracy: 0.8085
# Epoch 9/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5078 - binary_accuracy: 0.7730 - val_loss: 0.4875 - val_binary_accuracy: 0.8240
# Epoch 10/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5008 - binary_accuracy: 0.7710 - val_loss: 0.4746 - val_binary_accuracy: 0.8250
# Epoch 11/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5054 - binary_accuracy: 0.7800 - val_loss: 0.4657 - val_binary_accuracy: 0.8325
# Epoch 12/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4845 - binary_accuracy: 0.7855 - val_loss: 0.4541 - val_binary_accuracy: 0.8465
# Epoch 13/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4687 - binary_accuracy: 0.7985 - val_loss: 0.4405 - val_binary_accuracy: 0.8580
# Epoch 14/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4664 - binary_accuracy: 0.7925 - val_loss: 0.4346 - val_binary_accuracy: 0.8675
# Epoch 15/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4654 - binary_accuracy: 0.8035 - val_loss: 0.4344 - val_binary_accuracy: 0.8645
# Epoch 16/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4441 - binary_accuracy: 0.8060 - val_loss: 0.4161 - val_binary_accuracy: 0.8755
# Epoch 17/20
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4255 - binary_accuracy: 0.8105 - val_loss: 0.3933 - val_binary_accuracy: 0.8810
# Epoch 18/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4319 - binary_accuracy: 0.8175 - val_loss: 0.3874 - val_binary_accuracy: 0.8880
# Epoch 19/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4193 - binary_accuracy: 0.8280 - val_loss: 0.3896 - val_binary_accuracy: 0.8940
# Epoch 20/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4144 - binary_accuracy: 0.8230 - val_loss: 0.3866 - val_binary_accuracy: 0.8960

# %%
evaluate_on_dev(debug=debug)
# Out:
# 100it [00:00, 1273.53it/s]
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a3460>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# <utility_script_people_classification.InputSample object at 0x7d45a8340670>
# <utility_script_people_classification.InputSample object at 0x7d45d84a12a0>
# start to do validation, data size = 100
# 1/1 [==============================] - 0s 99ms/step
# Title:Douglas_Adams
# [ wrong prediction ] this person does not have the occupations:{'yago:Politician'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Screenwriter'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Paul_Otlet
# [ wrong prediction ] this person does not have the occupations:{'yago:Historian'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Lawyer'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:George_W._Bush
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Augusto_Pinochet
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Charles_Baudelaire
# [ missing prediction ] your prediction miss the occupations:{'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Nicolaus_Copernicus
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Physician'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Neil_Young
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_actor', 'yago:Singer', 'yago:Musician', 'yago:Film_director', 'yago:Actor'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Plato
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Indira_Gandhi
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Hector_Berlioz
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Journalist', 'yago:Composer'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Oscar_Luigi_Scalfaro
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Lawyer', 'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Ban_Ki-moon
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Leonard_Cohen
# [ wrong prediction ] this person does not have the occupations:{'yago:Film_director', 'yago:Historian', 'yago:Politician'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Musician', 'yago:Film_actor', 'yago:Screenwriter', 'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Osama_bin_Laden
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Historian', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Businessperson'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Gordian_III
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Sidney_Govou
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Bacary_Sagna
# [ wrong prediction ] this person does not have the occupations:{'yago:Film_director', 'yago:Historian', 'yago:Actor'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Football_player'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Jacques_Chirac
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Georges_Pompidou
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Ludwig_Erhard
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician', 'yago:University_teacher'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Helmut_Kohl
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Historian', 'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Elisha_E._Meredith
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Lawyer', 'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Hubert_Clifford
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Composer'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Yukiko_Kobayashi
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_actor', 'yago:Actor'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Jack_Angel
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_actor'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:V._P._Kalairajan
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Louis_Aragon
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Journalist', 'yago:Historian', 'yago:Politician', 'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Michel_Platini
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Tom_DeLonge
# [ wrong prediction ] this person does not have the occupations:{'yago:Film_director', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Singer'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Jon_Abrahams
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_actor'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Stefanie_Heinzmann
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Politician', 'yago:Actor', 'yago:Poet'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Singer'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Anna_Faris
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_actor', 'yago:Singer', 'yago:Actor'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Mitt_Romney
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician', 'yago:Businessperson'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Comtessa_de_Dia
# [ wrong prediction ] this person does not have the occupations:{'yago:Politician'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Writer', 'yago:Composer', 'yago:Actor'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Birger_Kildal
# [ missing prediction ] your prediction miss the occupations:{'yago:Lawyer', 'yago:Politician', 'yago:Businessperson'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Blondel_de_Nesle
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Politician'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Singer', 'yago:Composer'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:William_IX,_Duke_of_Aquitaine
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Composer', 'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Maria_de_Ventadorn
# [ missing prediction ] your prediction miss the occupations:{'yago:Composer', 'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:David_Bowie
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter', 'yago:Film_actor', 'yago:Composer', 'yago:Singer', 'yago:Actor'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Isabella_Teotochi_Albrizzi
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# ---------------------------
# 1/1 [==============================] - 0s 16ms/step
# Title:Andrea_del_Sarto
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Hokusai
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Antonello_da_Messina
# [ wrong prediction ] this person does not have the occupations:{'yago:Politician', 'yago:Film_director', 'yago:Historian', 'yago:Actor'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Abu_Nuwas
# [ wrong prediction ] this person does not have the occupations:{'yago:Politician', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Quintus_Curtius_Rufus
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Hebe_Camargo
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_actor', 'yago:Singer'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Tess_Gerritsen
# [ missing prediction ] your prediction miss the occupations:{'yago:Physician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Annette_Salmeen
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer'}
# [ missing prediction ] your prediction miss the occupations:{'yago:University_teacher'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Otto_Frank
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Businessperson'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Jing_Li_(chemist)
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Researcher'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Grazia_Deledda
# [ missing prediction ] your prediction miss the occupations:{'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Ambrogio_Bergognone
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Politician'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Ivan_the_Terrible
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Jamie_Selkirk
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Actor'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Lorenzo_di_Credi
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter'}
# ---------------------------
# 1/1 [==============================] - 0s 21ms/step
# Title:Aemilius_Macer
# [ wrong prediction ] this person does not have the occupations:{'yago:Historian', 'yago:Politician'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Augustin-Louis_Cauchy
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:University_teacher'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Lucius_Varius_Rufus
# [ missing prediction ] your prediction miss the occupations:{'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Joey_Moe
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Singer'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Parmigianino
# [ wrong prediction ] this person does not have the occupations:{'yago:Film_director', 'yago:Historian', 'yago:Actor'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Muhammad
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Martin_Luther
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Lawyer'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Richard_Nixon
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Kelly_Smith
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Politician', 'yago:Poet'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Football_player'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Hongzhi_Emperor
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Military_personnel', 'yago:Politician', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter'}
# ---------------------------
# 1/1 [==============================] - 0s 21ms/step
# Title:Tom_Cleverley
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Mark_Yeates
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Rachel_Yankey
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Stephen_Breyer
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Lawyer', 'yago:Politician', 'yago:University_teacher'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Susan_L._Graham
# [ missing prediction ] your prediction miss the occupations:{'yago:University_teacher'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:David_Paterson
# [ wrong prediction ] this person does not have the occupations:{'yago:Film_director', 'yago:Historian', 'yago:Actor', 'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Inna
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Singer'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Julio_Baghy
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Actor', 'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Bertilo_Wennergren
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Musician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Hisashi_Inoue
# [ missing prediction ] your prediction miss the occupations:{'yago:Writer', 'yago:Screenwriter'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Pierre-Alain_Muet
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Jean-Louis_Touraine
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Physician', 'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Michel_Terrot
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 46ms/step
# Title:Leopold_I_of_Belgium
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Military_personnel', 'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Tivadar_Soros
# [ missing prediction ] your prediction miss the occupations:{'yago:Writer', 'yago:Lawyer'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Mathieu_Gorgelin
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Luchino_Visconti
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_director', 'yago:Screenwriter'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Moby
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Film_director', 'yago:Historian'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Singer', 'yago:Musician', 'yago:Composer'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Ileana_Streinu
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:University_teacher'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Bill_Raisch
# [ missing prediction ] your prediction miss the occupations:{'yago:Film_actor'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Gaston_Eyskens
# [ missing prediction ] your prediction miss the occupations:{'yago:Painter', 'yago:University_teacher'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Donald_Tsang
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Lil_Wayne
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Politician', 'yago:Football_player', 'yago:Poet'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Singer'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Simon_Jenko
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician', 'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Milan_Jesih
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Poet'}
# ---------------------------
# 1/1 [==============================] - 0s 20ms/step
# Title:Walter_Breisky
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Montesquieu
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Historian', 'yago:Politician', 'yago:Lawyer'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Gaston_Geens
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Mario_Benedetti
# [ wrong prediction ] this person does not have the occupations:{'yago:Film_actor', 'yago:Researcher', 'yago:Military_personnel', 'yago:Composer', 'yago:Football_player', 'yago:Singer', 'yago:Historian', 'yago:Musician', 'yago:Film_director', 'yago:Lawyer', 'yago:Actor', 'yago:University_teacher'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Journalist'}
# ---------------------------
# 1/1 [==============================] - 0s 18ms/step
# Title:Wen_Jiabao
# [ wrong prediction ] this person does not have the occupations:{'yago:Writer', 'yago:Historian'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Politician'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Vsevolod_Solovyov
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Xavi
# ---------------------------
# 1/1 [==============================] - 0s 35ms/step
# Title:Roberto_Trashorras
# ---------------------------
# 1/1 [==============================] - 0s 19ms/step
# Title:Anatoly_Lunacharsky
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player', 'yago:Poet'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Journalist', 'yago:Actor'}
# ---------------------------
# 1/1 [==============================] - 0s 17ms/step
# Title:Sam_Witwer
# [ wrong prediction ] this person does not have the occupations:{'yago:Football_player'}
# [ missing prediction ] your prediction miss the occupations:{'yago:Musician', 'yago:Film_actor', 'yago:Actor'}
# ---------------------------
# result on validation set, f1 : 0.2258953168044077, precision : 0.21808510638297873, recall : 0.2342857142857143.

# %%
predict_on_test(debug=debug)
# Out:
# 100it [00:00, 1568.77it/s]
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# <utility_script_people_classification.InputSample object at 0x7d45def17130>
# <utility_script_people_classification.InputSample object at 0x7d45def17100>
# 0it [00:00, ?it/s]
# 1/1 [==============================] - 0s 60ms/step
# 1it [00:00,  8.85it/s]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 3it [00:00, 13.77it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 5it [00:00, 15.37it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 7it [00:00, 16.19it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 9it [00:00, 16.87it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 11it [00:00, 17.13it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 13it [00:00, 15.93it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 53ms/step
# 15it [00:00, 14.61it/s]
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 17it [00:01, 11.83it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 19it [00:01, 13.30it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 21it [00:01, 14.36it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 23it [00:01, 15.28it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 25it [00:01, 16.03it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 27it [00:01, 16.73it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 29it [00:01, 17.31it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 31it [00:01, 17.46it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 33it [00:02, 17.85it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 35it [00:02, 18.19it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 37it [00:02, 18.67it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 39it [00:02, 18.61it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 41it [00:02, 18.56it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 43it [00:02, 18.70it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 45it [00:02, 18.85it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 47it [00:02, 19.02it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 49it [00:02, 18.49it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 51it [00:03, 18.47it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 53it [00:03, 18.68it/s]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 55it [00:03, 18.76it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 57it [00:03, 18.67it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 59it [00:03, 17.76it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 61it [00:03, 18.12it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 63it [00:03, 18.37it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 65it [00:03, 18.58it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 67it [00:03, 18.47it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 70it [00:04, 19.14it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 72it [00:04, 19.31it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 74it [00:04, 19.34it/s]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 76it [00:04, 18.78it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 78it [00:04, 18.24it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 80it [00:04, 18.34it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 38ms/step
# 82it [00:04, 16.18it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 84it [00:04, 16.66it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 86it [00:04, 17.37it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 88it [00:05, 17.86it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 90it [00:05, 17.88it/s]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 92it [00:05, 17.75it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 94it [00:05, 17.58it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 96it [00:05, 17.48it/s]
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 98it [00:05, 17.92it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 100it [00:05, 17.33it/s]

# %% [markdown]
# We obtain an f1 score of 0.70, precision of 0.88 and recall of 0.58. This architecture allows us to reach a good precision level thanks to word embedding.
# A high precision rate means that on the predicted labels, there are few false negatives and false positives. The recall rate is lower, meaning the rate of predicted values on total true labels is lower. Effectively, by looking at the result.json file in output, we have some missing predictions. This induces a f1_score of 0.7.
#
# To put it in a nutshell, the model implemented does not make a lot of mistakes in prediction but it can miss to predict. Maybe a deeper network with more layers or higher number of epochs can improve performances.
